# %%
# Import libraries
import numpy as np
import pandas as pd
import unicodedata
import nltk
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix, roc_curve, auc, roc_auc_score

# %%
# Open dataset
jobs_labeled = pd.read_csv('../job-etl/data/csv/job_20221116.csv', usecols=[0, 1, 13], nrows=600)
jobs_labeled.head()
# Out:
#            id                                              title  it_spec
# 0  3301070910  (Brazil) Junior Business Development Specialis...        0
# 1  3264776485  (Evento SEnEC) - Desenvolvedor SW Junior - Clo...        1
# 2  3306116559                    (G) Técnico De Suporte - Júnior        1
# 3  3325496787                     [Meios de pagamento] QA Júnior        1
# 4  3303776344                        Academia SAP UTILITIES 2022        0

# %%
# Regex Preprocessing

# Lowercase titles
jobs_labeled['clean_title'] = jobs_labeled['title'].str.lower()

# Remove whitespaces
jobs_labeled['clean_title'] = jobs_labeled['clean_title'].str.strip()

# Remove digits
jobs_labeled['clean_title'] = jobs_labeled['clean_title'].str.replace('\d', '')

# Remove special characters
jobs_labeled['clean_title'] = jobs_labeled['clean_title'].str.replace('\(|\)|/|-|\[|\]|\,|:|%','')

# Remove unicode characters
jobs_labeled['clean_title'] = jobs_labeled['clean_title'].map(lambda x: unicodedata.normalize('NFD', x))
jobs_labeled['clean_title'] = jobs_labeled['clean_title'].str.encode('ascii', 'ignore')
jobs_labeled['clean_title'] = jobs_labeled['clean_title'].str.decode('utf-8')

jobs_labeled.sample(10)
# Out:
# /tmp/ipykernel_24358/2375048862.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   jobs_labeled['clean_title'] = jobs_labeled['clean_title'].str.replace('\d', '')
# /tmp/ipykernel_24358/2375048862.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   jobs_labeled['clean_title'] = jobs_labeled['clean_title'].str.replace('\(|\)|/|-|\[|\]|\,|:|%','')
#              id                                             title  it_spec  \
# 587  3333849701               Remote Junior Python Developer Jobs        1
# 401  3305317615  Engenheiro(a) de Produtos e Projetos Eletrônicos        1
# 503  3298020363                           Programador .net Júnior        1
# 155  3324234729                         Analista de Testes Junior        1
# 317  3276627342                    Desenvolvedor Front-End Júnior        1
# 203  3315663206                  App Dev Architecture - Sao Paulo        1
# 72   3278328551              Analista de Marketing Digital Junior        0
# 191  3295013691                         Analista rpa junior/pleno        1
# 13   3338928763                    Analista Administrativo Junior        0
# 561  3297653360                      Remote Golang Developer Jobs        1
#
#                                         clean_title
# 587             remote junior python developer jobs
# 401  engenheiroa de produtos e projetos eletronicos
# 503                         programador .net junior
# 155                       analista de testes junior
# 317                   desenvolvedor frontend junior
# 203                 app dev architecture  sao paulo
# 72             analista de marketing digital junior
# 191                        analista rpa juniorpleno
# 13                   analista administrativo junior
# 561                    remote golang developer jobs

# %%
# Remove stopwords and lemmatize
def remove_stopwords(string):
    # Remove stopwords
    stopwordslist = set(stopwords.words(['english', 'portuguese', 'spanish']))
    meaningful_words = [i for i in string.split() if i not in stopwordslist]
    return ' '.join(meaningful_words).lower()


jobs_labeled['clean_title'] = jobs_labeled['clean_title'].apply(lambda x: remove_stopwords(x))
jobs_labeled.sample(10)
# Out:
#              id                                           title  it_spec  \
# 530  3312290593                       Remote Data Engineer Jobs        1
# 223  3315658998                App Dev Architecture - Sao Paulo        1
# 24   3282179708    Analista Contábil Junior - Espanhol Avançado        0
# 152  3314239700                              Analista de Testes        1
# 200  3334690232                          Analyst Support Junior        1
# 246  3333421896                               Assistente Fiscal        0
# 303  3331700984                 Desenvolvedor de Backend Júnior        1
# 589  3312290620            Remote Junior Software Engineer Jobs        1
# 568  3333852513        Remote Junior Application Developer Jobs        1
# 232  3271369106  Assistente De Compras Junior -Hortolândia - Sp        0
#
#                                     clean_title
# 530                   remote data engineer jobs
# 223              app dev architecture sao paulo
# 24   analista contabil junior espanhol avancado
# 152                             analista testes
# 200                      analyst support junior
# 246                           assistente fiscal
# 303                desenvolvedor backend junior
# 589        remote junior software engineer jobs
# 568    remote junior application developer jobs
# 232    assistente compras junior hortolandia sp

# %%
# Split data into train an test sets
X_train, X_test, y_train, y_test = train_test_split(jobs_labeled['clean_title'],jobs_labeled['it_spec'],test_size=0.5,shuffle=True)

#Word2Vec
# Word2Vec runs on tokenized sentences
X_train_tok= [nltk.word_tokenize(i) for i in X_train]  
X_test_tok= [nltk.word_tokenize(i) for i in X_test]
X_train_tok
# Out:
# [['desenvolvedor', 'mobile', 'androidkotlin', 'senior'],
#  ['remote', 'backend', 'developer', 'jobs'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['analista', 'contas', 'pagar', 'junior', 'espanhol', 'avancado'],
#  ['remote', 'fullstack', 'developer', 'jobs'],
#  ['analista', 'atendimento', 'junior'],
#  ['analista', 'suporte', 'junior'],
#  ['inside', 'sales', 'jr'],
#  ['recreacionista', 'junior', 'atibaia', 'sp'],
#  ['junior', 'software', 'architect', 'mckinsey', 'digital'],
#  ['assistente', 'desenvolvimento', 'java'],
#  ['desenvolvedor', 'net', 'windows', 'forms', 'junior', 'nh', 'rs'],
#  ['analista', 'testes', 'junior'],
#  ['programador', 'junior'],
#  ['desenvolvedor', 'junior', 'fullstack'],
#  ['assistente', 'administrativo', 'junior'],
#  ['analista', 'contas', 'pagar', 'junior', 'espanhol', 'avancado'],
#  ['remote', 'junior', 'c++', 'backend', 'engineer', 'jobs'],
#  ['comercial', 'especialidade', 'seguranca', 'junior'],
#  ['desenvolvedor', 'junior', 'laravelcssjs'],
#  ['remote', 'react', 'native', 'developer', 'jobs'],
#  ['junior', 'pi', 'osi', 'analyst'],
#  ['junior',
#   'business',
#   'analyst',
#   'vaga',
#   'afirmativa',
#   'pessoas',
#   'deficiencia'],
#  ['desenvolvedor', 'full', 'stak', 'junior', 'hibrido', 'curitibapr'],
#  ['desenvolvedor', 'java', 'pleno'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['programador', 'java', 'junior', 'banco', 'talentos'],
#  ['desenvolvedora', 'full', 'stack', 'junior'],
#  ['remote', 'junior', 'software', 'engineer', 'jobs'],
#  ['executivo', 'vendas', 'junior', 'pcd'],
#  ['analista', 'programador', 'security', 'vagas'],
#  ['desenvolvedor', 'full', 'stack', 'delphi', 'plsql', '|', 'junior'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['full', 'stack', 'developer', 'react', 'junior', 'remoto'],
#  ['analista', 'testes', 'junior'],
#  ['junior',
#   'business',
#   'analyst',
#   'vaga',
#   'afirmativa',
#   'pessoas',
#   'deficiencia'],
#  ['analista', 'marketing', 'digital', 'junior'],
#  ['desenvolvedora', 'java', 'junior'],
#  ['cyber', 'threat', 'intelligence', 'analyst'],
#  ['analista', 'programador', 'sdai', 'vagas'],
#  ['analista',
#   'administrativo',
#   'bilingue',
#   'junior',
#   'preferencial',
#   'profissionais',
#   'deficiencia'],
#  ['pessoa', 'product', 'manager', 'junior', 'data', '&', 'analytics'],
#  ['desenvolvedor', 'backend', 'java'],
#  ['front',
#   'end',
#   'marketing',
#   'automation',
#   'junior',
#   'vaga',
#   'afirmativa',
#   'pcd'],
#  ['information', 'technology', 'help', 'desk'],
#  ['remote', 'data', 'engineer', 'jobs'],
#  ['assistente', 'desenvolvimento', 'java'],
#  ['analista', 'administrativo', 'junior'],
#  ['remote', 'data', 'analyst', 'scientist', 'jobs'],
#  ['analista', 'customer', 'services', 'junior'],
#  ['remote', 'python', 'developer', 'jobs'],
#  ['fieldguide',
#   'lead',
#   'product',
#   'designer',
#   'direct',
#   'hire',
#   'direct',
#   'hire',
#   'remote'],
#  ['remote', 'fullstack', 'engineer', 'jobs'],
#  ['analista', 'faturamento', 'junior'],
#  ['pessoa', 'analista', 'service', 'desk', 'junior'],
#  ['desenvolvedor', '.net', 'junior'],
#  ['analista', 'suporte', 'junior'],
#  ['remote', 'junior', 'ai', 'developer', 'jobs'],
#  ['assistente', 'materiais', 'junior', 'americana', 'sp'],
#  ['remote', 'full', 'stack', 'developer', 'jobs'],
#  ['designer', 'junior', 'home', 'office'],
#  ['analista', 'customer', 'services', 'junior', 'x'],
#  ['analista', 'testes'],
#  ['junior', 'software', 'developer'],
#  ['desenvolvedor', 'c', '#', 'vb', 'junior', 'pleno'],
#  ['remote', 'fullstack', 'engineer', 'jobs'],
#  ['frontend', 'developer', 'remote'],
#  ['remote', 'fullstack', 'developer', 'jobs'],
#  ['desenvolvedor', 'junior', 'pleno', 'home', 'office'],
#  ['analista', 'dev', 'jr.', 'netsuite'],
#  ['analista', 'negocios', 'junior'],
#  ['remote', 'junior', 'java', 'architect', 'jobs'],
#  ['analista', 'marketing', 'junior'],
#  ['analista', 'programador', 'sdai'],
#  ['assistente', 'bi', 'junior'],
#  ['remote', 'junior', 'software', 'engineer', 'jobs'],
#  ['meios', 'pagamento', 'qa', 'junior'],
#  ['analista', 'suporte', 'junior'],
#  ['assistente', 'fiscal', 'junior'],
#  ['remote', 'fullstack', 'developer', 'jobs'],
#  ['assistente', 'suporte', 'junior'],
#  ['auxiliar', 'tecnologia', 'informacao', 'junior'],
#  ['analista', 'inbound', 'marketing', 'junior'],
#  ['remote', 'golang', 'developer', 'jobs'],
#  ['desenvolvedor', 'full', 'stack', 'junior'],
#  ['analista', 'marketing', 'junior'],
#  ['analista', 'powerapp', 'microsoft', 'juniorpleno'],
#  ['analista', 'faturamento', 'junior'],
#  ['engenheiro', 'eletronico', 'pleno'],
#  ['analista', 'suporte', 'junior', 'smarsa'],
#  ['programador', 'java', 'junior'],
#  ['designer', 'junior', 'assistente', 'arte'],
#  ['remote', 'fullstack', 'developer', 'jobs'],
#  ['designer', 'junior', 'assistente', 'arte'],
#  ['remote', 'frontend', 'developer', 'jobs'],
#  ['pessoa', 'desenvolvedora', '.net', 'junior'],
#  ['estagio', 'ldr', 'lead', 'development', 'representative'],
#  ['analista', 'contabil', 'junior'],
#  ['programador', 'junior'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['analista', 'contabil', 'junior', 'espanhol', 'avancado'],
#  ['desenvolvedor', 'c', '#', 'asp.net', 'mvc', 'fullstack', 'junior'],
#  ['engenheiroa', 'obras', '|', 'site', 'engineer', 'c'],
#  ['analista', 'programador', 'bms'],
#  ['analista', 'suporte', 'junior'],
#  ['atendente', 'armazem', 'junior', 'campinas', 'sp'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['analista', 'suporte', 'junior'],
#  ['analista', 'contabil', 'junior', 'espanhol', 'avancado'],
#  ['ajudante', 'geral', 'junior', 'guarulhos', 'pq', 'naes'],
#  ['analista', 'planejamento', 'junior'],
#  ['remote', 'fullstack', 'engineer', 'jobs'],
#  ['desenvolvedor', 'junior', '.net', 'c', '#', 'presencial'],
#  ['remote', 'frontend', 'developer', 'jobs'],
#  ['desenvolvedor', 'frontend', 'junior', 'pleno', 'snior'],
#  ['executivo', 'contas', 'junior'],
#  ['junior', 'consultant', 'funding', 'instruments', 'roma', 'cns'],
#  ['engenheiroa', 'produtos', 'projetos', 'eletronicos'],
#  ['analista', 'suporte', 'junior', 'alphaville'],
#  ['analista', 'suporte', 'junior', 'campinas', 'vaga'],
#  ['analista', 'programador', 'bms', 'vagas'],
#  ['desenvolvedor', 'backend', 'junior', 'pleno'],
#  ['analista', 'suporte', 'junior', 'bilingue'],
#  ['remote', 'node.js', 'developer', 'jobs'],
#  ['pessoa',
#   'uiux',
#   'designer',
#   'junior',
#   'vaga',
#   'exclusiva',
#   'afirmativa',
#   'pessoas',
#   'negras'],
#  ['backend', 'developer'],
#  ['analista', 'suporte', 'pleno'],
#  ['estagio', 'parcerias', 'institucionais'],
#  ['assistente', 'fiscal'],
#  ['remote', 'google', 'cloud', 'platform', 'engineer', 'jobs'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['desenvolvedor', 'full', 'stack', 'junior'],
#  ['junior', 'software', 'engineer', 'trilogy', 'remote', '$', 'year', 'usd'],
#  ['assistente', 'contabil', 'junior'],
#  ['remote', 'junior', 'application', 'developer', 'jobs'],
#  ['desenvolvedora', '.net', 'c', '#', 'junior'],
#  ['analista', 'contabil', 'junior', 'espanhol', 'avancado'],
#  ['intern', 'data', 'consultant', 'sao', 'paulo', 'october'],
#  ['executivo', 'contas', 'junior'],
#  ['especialistas', 'seguranca', 'informacao'],
#  ['assistente', 'tecnico', 'eletronica', 'junior', 'reparo', 'placas'],
#  ['programador', '.net', 'junior'],
#  ['analista', 'marketing', 'junior'],
#  ['desenvolvedor', 'java', 'full', 'stack', 'junior', 'sao', 'paulo'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['desenvolvedor', 'full', 'stack', 'delphi', 'pl', 'sql', 'junior'],
#  ['jr.', 'customer', 'support', 'analyst'],
#  ['analista', 'compras', 'junior', 'valinhos', 'sp'],
#  ['analista', 'suporte', 'junior'],
#  ['analista', 'suporte', 'junior'],
#  ['analista', 'suporte', 'junior'],
#  ['programador', 'junior'],
#  ['infrastructure', 'expert', 'support', 'engineer', 'latam'],
#  ['advogadoa', 'junior'],
#  ['jr.', 'customer', 'support', 'analyst'],
#  ['analista', 'juridico', 'financeiro', 'junior', 'auditoria'],
#  ['remote', 'junior', 'python', 'developer', 'jobs'],
#  ['analista', 'suporte', 'junior'],
#  ['analista', 'suporte', 'junior'],
#  ['desenvolvedor', 'sdk', 'junior', 'iii'],
#  ['desenvolvedor', 'c', '#', 'vb', 'junior', 'pleno'],
#  ['desenvolvedor', 'software', 'junior', 'exclusivo', 'pcd'],
#  ['especialistas', 'seguranca', 'informacao'],
#  ['analista', 'dev', 'jr.', 'netsuite'],
#  ['mastercard',
#   'software',
#   'engineer',
#   'ii',
#   'blockchain',
#   'direct',
#   'hire',
#   'remote'],
#  ['analista', 'suporte', 'junior'],
#  ['analista', 'powerapp', 'microsoft', 'juniorpleno'],
#  ['remote', 'frontend', 'engineer', 'jobs'],
#  ['desenhista', 'industrial', 'juniorsumare', 'sp'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['junior', 'scala', 'engineer'],
#  ['analista',
#   'qa',
#   'automatizado',
#   '|',
#   'junior',
#   'programa',
#   'datum',
#   'geracao'],
#  ['pcd', 'tecnico', 'suporte', 'junior'],
#  ['remote', 'junior', 'frontend', 'developer', 'jobs'],
#  ['recreacionista', 'junior', 'atibaia', 'sp'],
#  ['engenheiroa', 'obras', '|', 'site', 'engineer', 'c'],
#  ['academia', 'sap', 'utilities'],
#  ['analista', 'gestao', 'projetos', 'junior'],
#  ['remote', 'backend', 'developer', 'jobs'],
#  ['assistente', 'fiscal'],
#  ['inside', 'sales', 'junior', 'curitiba'],
#  ['analista', 'desenvolvimento', 'junior', 'remoto'],
#  ['junior', 'analyst'],
#  ['estagiario', 'gestao', 'comunidades'],
#  ['auxiliar', 'mecanico', 'junior', 'santo', 'andre', 'sp'],
#  ['desenvolvedora', 'sql', 'server', 'junior'],
#  ['analista', 'desenvolvimento', '.net', 'junior', 'remoto'],
#  ['g', 'tecnico', 'suporte', 'junior'],
#  ['junior', 'full', 'stack', 'engineer'],
#  ['desenvolvedor', 'fullstack', 'java', 'junior'],
#  ['analista', 'sustentacao', 'sistemas', 'junior', 'hibrido', 'curitibapr'],
#  ['analista', 'field', 'junior', 'pleno'],
#  ['analista', 'suporte', 'junior'],
#  ['analista', 'desenvolvimento', '.net', 'junior', 'remoto'],
#  ['analista', 'rpa', 'juniorpleno'],
#  ['analista', 'testes', 'junior'],
#  ['analista', 'contabil', 'junior', 'espanhol', 'avancado'],
#  ['desenvolvedora', '.net', 'c', '#', 'junior'],
#  ['assistente', 'contabil', 'junior'],
#  ['remote', 'machine', 'learning', 'engineer', 'jobs'],
#  ['analista', 'contas', 'pagar', 'junior', 'espanhol', 'avancado'],
#  ['business', 'analyst', 'junior'],
#  ['analista', 'contabil', 'junior'],
#  ['assistente', 'fiscal'],
#  ['desenvolvedora', 'java', 'junior', 'afirmativa', 'mulheres'],
#  ['analista', 'desenvolvedor', 'junior'],
#  ['pessoa', 'assistente', 'projetos', 'junior'],
#  ['desenvolvedora', 'java', 'junior'],
#  ['programador', 'junior'],
#  ['analista', 'suporte', 'implantacao', 'junior', 'erp'],
#  ['developer', 'full', 'stack', 'junior', 'exclusiva', 'pcd'],
#  ['junior', 'financial', 'analyst'],
#  ['remote', 'fullstack', 'developer', 'jobs'],
#  ['dev', 'frontend', 'vuejsangular', 'junior'],
#  ['remote', 'junior', 'fullstack', 'developer', 'jobs'],
#  ['desenvolvedor', 'full', 'stak', 'junior', 'hibrido', 'curitibapr'],
#  ['desenvolvedor', 'software'],
#  ['analista', 'credito', 'junior'],
#  ['desenvolvedora', 'full', 'stack', 'junior'],
#  ['programador', 'web', 'junior'],
#  ['analista', 'financeiro', 'jr'],
#  ['desenvolvedor', '.net', 'windows', 'forms', 'junior', 'nh', 'rs'],
#  ['estagio', 'inteligencia', 'negocios'],
#  ['delphi', 'programmer', 'junior'],
#  ['atendente', 'suporte', 'junior'],
#  ['analista', 'contabil', 'junior'],
#  ['consultor', 'microsoft', 'junior', 'pleno'],
#  ['remote', 'fullstack', 'developer', 'jobs'],
#  ['consultor', 'comercial', 'junior'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['junior', 'aqa', 'engineer'],
#  ['evento', 'senec', 'desenvolvedor', 'sw', 'junior', 'cloudbackend'],
#  ['analista', 'suporte', 'junior'],
#  ['analista', 'marketing', 'junior'],
#  ['remote', 'junior', 'fullstack', 'developer', 'jobs'],
#  ['analista', 'contabil', 'junior', 'espanhol', 'avancado'],
#  ['analista', 'sistemas', 'junior'],
#  ['analista', 'programador', 'av'],
#  ['desenvolvedor', 'sap', 'shana', 'junior'],
#  ['remote', 'fullstack', 'php', 'developer', 'jobs'],
#  ['comprador', 'junior'],
#  ['junior', 'technical', 'email', 'marketing', 'specialist'],
#  ['remote', 'fullstack', 'developer', 'jobs'],
#  ['remote', 'frontend', 'developer', 'jobs'],
#  ['desenvolvedora', 'java', 'junior'],
#  ['analista',
#   'treinamento',
#   'junior',
#   'foco',
#   'treinamento',
#   'desenvolvimento'],
#  ['desenhista', 'cad', 'junior', 'sumare', 'sp'],
#  ['analista', 'suporte', 'vendas', 'junior'],
#  ['analista', 'compras', 'junior'],
#  ['analista', 'marketing', 'digital', 'junior'],
#  ['analista', 'suporte', 'tecnico', 'junior'],
#  ['analista', 'negocios'],
#  ['remote', 'data', 'engineer', 'jobs'],
#  ['remote', 'fullstack', 'wordpress', 'developer', 'jobs'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['engenheiro', 'machine', 'learning', 'junior', 'remoto'],
#  ['remote', 'node.js', 'developer', 'jobs'],
#  ['desenhista', 'cadista', 'junior'],
#  ['desenvolvedor', 'java', 'pleno'],
#  ['assistente', 'infra', 'junior'],
#  ['analista', 'sistemas', 'junior'],
#  ['desenvolvedor', 'rpa'],
#  ['assistente', 'tecnico', 'eletronica', 'junior', 'reparo', 'placas'],
#  ['pessoa', 'assistente', 'projetos', 'junior'],
#  ['analista', 'prestacao', 'contas', 'junior'],
#  ['remote', 'react', 'native', 'developer', 'jobs'],
#  ['gerente', 'junior', 'relacionamento', 'fashion', 'vaga', 'temporaria'],
#  ['remote', 'junior', 'frontend', 'developer', 'jobs'],
#  ['auxiliar', 'suporte', 'tecnico', 'junior'],
#  ['estagio', 'inovacao'],
#  ['remote', 'junior', 'c++', 'backend', 'engineer', 'jobs'],
#  ['desenvolvedora', '.net', 'c', '#', 'junior'],
#  ['desenvolvedora', 'python', 'full', 'stack', 'junior'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['analista', 'suporte', 'pleno'],
#  ['estoquista', 'junior'],
#  ['desenvolvedor', 'webnivel', 'junior'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['analista', 'prevendas', 'junior'],
#  ['junior', 'consultant'],
#  ['desenvolvedora', 'fullstack', 'senior'],
#  ['remote', 'perl', 'developer', 'jobs'],
#  ['desenvolvedor', 'frontend', 'junior'],
#  ['desenvolvedor', 'juniorpleno'],
#  ['app', 'dev', 'architecture', 'sao', 'paulo'],
#  ['analyst', 'gerente', 'projetos', 'junior'],
#  ['desenvolvedor', 'full', 'stack', 'delphi', 'plsql', '|', 'junior'],
#  ['executivo', 'conta', 'account', 'executive', 'junior'],
#  ['analista', 'suporte', 'cliente'],
#  ['analyst', 'help', 'desk'],
#  ['remote', 'data', 'engineer', 'jobs'],
#  ['analista', 'suporte', 'junior'],
#  ['analista',
#   'atendimento',
#   'junior',
#   'preferencial',
#   'profissionais',
#   'deficiencia'],
#  ['desenvolvedor', 'java', 'pleno'],
#  ['desenvolvedor', 'sistemas', 'php', 'junior'],
#  ['desenvolvedora', 'react', 'native', 'junior', 'fulltime', 'remoto'],
#  ['consultor', 'fiscal', 'junior'],
#  ['pessoa', 'analista', 'vendas', 'junior'],
#  ['desenvolvedor', 'java', 'pleno'],
#  ['desenvolvedor', 'microsoft', 'power', 'platform', 'junior']]

# %%
#Vectorize data
tfidf_vectorizer = TfidfVectorizer(use_idf=True)
X_train_vectors_tfidf = tfidf_vectorizer.fit_transform(X_train) 
X_test_vectors_tfidf = tfidf_vectorizer.transform(X_test)

#building Word2Vec model
class MeanEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        # if a text is empty we should return a vector of zeros
        # with the same dimensionality as all the other vectors
        self.dim = len(next(iter(word2vec.values())))
    def fit(self, X, y):
        return self
    def transform(self, X):
        return np.array([
            np.mean([self.word2vec[w] for w in words if w in self.word2vec]
                    or [np.zeros(self.dim)], axis=0)
            for words in X
        ])
jobs_labeled["clean_title_tok"] = [nltk.word_tokenize(i) for i in jobs_labeled['clean_title']]
model = Word2Vec(jobs_labeled["clean_title_tok"],min_count=1)     
w2v = dict(zip(model.wv.index_to_key, model.wv.vectors)) 
modelw = MeanEmbeddingVectorizer(w2v)

# converting text to numerical data using Word2Vec
X_train_vectors_w2v = modelw.transform(X_train_tok)
X_val_vectors_w2v = modelw.transform(X_test_tok)

# %%
# Logistic regression model for job classification (tf-idf)
lr_tfidf=LogisticRegression(solver = 'liblinear', C=10, penalty = 'l2')
lr_tfidf.fit(X_train_vectors_tfidf, y_train)  

# Predict y value for test dataset
y_predict = lr_tfidf.predict(X_test_vectors_tfidf)
y_prob = lr_tfidf.predict_proba(X_test_vectors_tfidf)[:,1]
print(classification_report(y_test,y_predict))
print('Confusion Matrix:',confusion_matrix(y_test, y_predict))
 
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
print('AUC:', roc_auc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83        92
#            1       0.91      0.95      0.93       208
#
#     accuracy                           0.90       300
#    macro avg       0.89      0.87      0.88       300
# weighted avg       0.90      0.90      0.90       300
#
# Confusion Matrix: [[ 73  19]
#  [ 11 197]]
# AUC: 0.9601797658862876

# %%
#Testing classification model on unlabeled dataset
jobs_unlabeled = pd.read_csv('../job-etl/data/csv/job_20221107.csv', usecols=[0, 1], skiprows=range(1,601))  #reading the data
jobs_unlabeled['clean_title'] = jobs_unlabeled['title'].apply(lambda x: remove_stopwords(x)) #preprocess the data
X_test = jobs_unlabeled['clean_title'] 
X_vector = tfidf_vectorizer.transform(X_test) #converting X_test to vector
y_predict = lr_tfidf.predict(X_vector)      #use the trained model on X_vector
y_prob = lr_tfidf.predict_proba(X_vector)[:,1].round(2)
jobs_unlabeled['predict_prob']= y_prob
jobs_unlabeled['auto_class']= y_predict
print(jobs_unlabeled.sample(10))
final=jobs_unlabeled[['id', 'clean_title','predict_prob', 'auto_class']].reset_index(drop=True)
final.to_csv('../job-etl/data/csv/job-auto-class.csv')
# Out:
#              id                                              title  \
# 103  3315659738                   App Dev Architecture - Sao Paulo
# 77   3269594547             Profissional Desenvolvedor Java Junior
# 90   3297404677                        Java Engineer - Remote Work
# 58   3297650937                        Remote Golang Engineer Jobs
# 143  3314276150                 Assistente de Desenvolvimento Java
# 14   3271068609  Cod:. J.S - Analista De Controladoria Junior -...
# 146  3297652550     Trabajos remotos de Ingeniero Líder Full Stack
# 52   3325658033       Analista Contábil Júnior - Espanhol Avançado
# 75   3304075129                      Work From Home Java Developer
# 105  3301070910  (Brazil) Junior Business Development Specialis...
#
#                                            clean_title  predict_prob  \
# 103                   app dev architecture - sao paulo          0.98
# 77              profissional desenvolvedor java junior          0.99
# 90                         java engineer - remote work          0.99
# 58                         remote golang engineer jobs          0.96
# 143                    assistente desenvolvimento java          0.92
# 14   cod:. j.s - analista de controladoria junior -...          0.30
# 146        trabajos remotos ingeniero líder full stack          0.94
# 52        analista contábil júnior - espanhol avançado          0.16
# 75                       work from home java developer          0.91
# 105  (brazil) junior business development specialis...          0.55
#
#      auto_class
# 103           1
# 77            1
# 90            1
# 58            1
# 143           1
# 14            0
# 146           1
# 52            0
# 75            1
# 105           1

# %%
# Join two tables for label comparison
merged_df = jobs_labeled.merge(jobs_unlabeled, how='outer', suffixes=('', '_auto'))
merged_df = merged_df[['id', 'title', 'clean_title','it_spec', 'auto_class', 'predict_prob']].reset_index(drop=True)
merged_df['equal'] = merged_df['it_spec'] == merged_df['auto_class']

# %%
merged_df.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            716 non-null    int64
#  1   title         716 non-null    object
#  2   clean_title   716 non-null    object
#  3   it_spec       600 non-null    float64
#  4   auto_class    150 non-null    float64
#  5   predict_prob  150 non-null    float64
#  6   equal         716 non-null    bool
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 34.4+ KB
